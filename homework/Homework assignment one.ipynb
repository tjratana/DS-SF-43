# %% [markdown]
# # Homework Assignment Number One

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Section 1: Police killings

# %%
killings = pd.read_csv('../data/police-killings.csv', encoding='cp1252', index_col=[0])
killings.head()
# Out:
#                  name  age gender    raceethnicity     month  day  year  \
# 0  A'donte Washington   16   Male            Black  February   23  2015
# 1      Aaron Rutledge   27   Male            White     April    2  2015
# 2         Aaron Siler   26   Male            White     March   14  2015
# 3        Aaron Valdez   25   Male  Hispanic/Latino     March   11  2015
# 4        Adam Jovicic   29   Male            White     March   19  2015
#
#             streetaddress          city state  \
# 0            Clearview Ln     Millbrook    AL
# 1  300 block Iris Park Dr     Pineville    LA
# 2    22nd Ave and 56th St       Kenosha    WI
# 3       3000 Seminole Ave    South Gate    CA
# 4          364 Hiwood Ave  Munroe Falls    OH
#
#               lawenforcementagency    cause    armed  county_income
# 0      Millbrook Police Department  Gunshot       No          54766
# 1  Rapides Parish Sheriff's Office  Gunshot       No          40930
# ...

# %% [markdown]
# ### 1. Make the following changes to column names:
#
# - lawenforcementagency -> agency
# - raceethnicity -> race

# %%
killings.rename(columns={'lawenforcementagency': 'agency', 'raceethnicity': 'race'})
# Out:
#                         name  age  gender             race     month  day  \
# 0         A'donte Washington   16    Male            Black  February   23
# 1             Aaron Rutledge   27    Male            White     April    2
# 2                Aaron Siler   26    Male            White     March   14
# 3               Aaron Valdez   25    Male  Hispanic/Latino     March   11
# 4               Adam Jovicic   29    Male            White     March   19
# 5              Adam Reinhart   29    Male            White     March    7
# 6           Adrian Hernandez   22    Male  Hispanic/Latino     March   27
# 7               Adrian Solis   35    Male  Hispanic/Latino     March   26
# 8              Alan Alverson   44    Male            White   January   28
# 9                 Alan James   31    Male            White  February    7
# 10          Albert Hanson Jr   76    Male            White     April   26
# 11            Alec Ouzounian   40    Male            White       May   12
# ...

# %% [markdown]
# ### 2. Show the count of missing values in each column

# %%
killings.isnull().sum()
# Out:
# name                    0
# age                     0
# gender                  0
# raceethnicity           0
# month                   0
# day                     0
# year                    0
# streetaddress           4
# city                    0
# state                   0
# lawenforcementagency    0
# cause                   0
# armed                   0
# county_income           0
# dtype: int64

# %% [markdown]
# ### 3. Replace each null value in the dataframe with the string "unknown"

# %%
killings.fillna("unknown")
# Out:
#                         name  age  gender    raceethnicity     month  day  \
# 0         A'donte Washington   16    Male            Black  February   23
# 1             Aaron Rutledge   27    Male            White     April    2
# 2                Aaron Siler   26    Male            White     March   14
# 3               Aaron Valdez   25    Male  Hispanic/Latino     March   11
# 4               Adam Jovicic   29    Male            White     March   19
# 5              Adam Reinhart   29    Male            White     March    7
# 6           Adrian Hernandez   22    Male  Hispanic/Latino     March   27
# 7               Adrian Solis   35    Male  Hispanic/Latino     March   26
# 8              Alan Alverson   44    Male            White   January   28
# 9                 Alan James   31    Male            White  February    7
# 10          Albert Hanson Jr   76    Male            White     April   26
# 11            Alec Ouzounian   40    Male            White       May   12
# ...

# %% [markdown]
# 4. How many killings were there in March and April?

# %%
killings.month.str.contains("March").sum()
# Out:
# 114

# %%
killings.month.str.contains("April").sum()
# Out:
# 96

# %% [markdown]
# ### 5. How many male and how many female victims are there?

# %%
killings.gender.str.contains("Female").sum()
# Out:
# 22

# %% [markdown]
# ### 6. How many killings were of unarmed people?

# %%
killings.armed.str.contains("No").sum()
# Out:
# 116

# %% [markdown]
# ### 7. What percentage of all killings were unarmed?

# %%
116 / 467
# Out:
# 0.24839400428265523

# %% [markdown]
# ### 8. What are the 5 states with the most killings?

# %%
Top5 = killings.state.value_counts()
Top5.head()
# Out:
# CA    74
# TX    46
# FL    29
# AZ    25
# OK    22
# Name: state, dtype: int64

# %% [markdown]
# ### 9. Show a value counts of deaths for each race

# %%
killings.raceethnicity.value_counts()
# Out:
# White                     236
# Black                     135
# Hispanic/Latino            67
# Unknown                    15
# Asian/Pacific Islander     10
# Native American             4
# Name: raceethnicity, dtype: int64

# %% [markdown]
# ### 10. Display a histogram of ages of all killings

# %%
killings.hist('age')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x113c6c438>]], dtype=object)

# %% [markdown]
# ### 11. Show histogram of ages for each race

# %%
killings.hist('age', by='raceethnicity', figsize=(20,18))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10c590898>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115a4bf98>]], dtype=object)

# %% [markdown]
# ### 12. What is the average age of death by race?

# %%
killings.groupby('raceethnicity').age.median()
# Out:
# raceethnicity
# Asian/Pacific Islander    36.5
# Black                     32.0
# Hispanic/Latino           31.0
# Native American           27.0
# Unknown                   40.0
# White                     39.0
# Name: age, dtype: float64

# %% [markdown]
# ### 13. Show a bar chart with counts of deaths every month

# %%
killings.month.value_counts()
# Out:
# March       114
# April        96
# January      90
# February     84
# May          81
# June          2
# Name: month, dtype: int64

# %%
Month = ["January", "February", "March", "April", "May", "June"]
Count = [90, 84, 114, 96, 81, 2]
pos = np.arange(len(Count))
w = 0.4
plt.bar(x=pos, width=w, height=Count,tick_label=Month, align="center")
plt.show()

# %% [markdown]
# ## Section 2: College Majors

# %%
majors = pd.read_csv('../data/college-majors.csv', index_col=[0])
majors
# Out:
#      Major_code                                              Major  \
# 0          1100                                GENERAL AGRICULTURE
# 1          1101              AGRICULTURE PRODUCTION AND MANAGEMENT
# 2          1102                             AGRICULTURAL ECONOMICS
# 3          1103                                    ANIMAL SCIENCES
# 4          1104                                       FOOD SCIENCE
# 5          1105                         PLANT SCIENCE AND AGRONOMY
# 6          1106                                       SOIL SCIENCE
# 7          1199                          MISCELLANEOUS AGRICULTURE
# 8          1301                              ENVIRONMENTAL SCIENCE
# 9          1302                                           FORESTRY
# 10         1303                       NATURAL RESOURCES MANAGEMENT
# 11         1401                                       ARCHITECTURE
# 12         1501               AREA ETHNIC AND CIVILIZATION STUDIES
# ...

# %% [markdown]
# ### 1. Delete the columns (employed_full_time_year_round, major_code)

# %%
majors1 = majors.drop(majors.columns[[0,5]], axis=1) 
majors1
# Out:
#                                                  Major  \
# 0                                  GENERAL AGRICULTURE
# 1                AGRICULTURE PRODUCTION AND MANAGEMENT
# 2                               AGRICULTURAL ECONOMICS
# 3                                      ANIMAL SCIENCES
# 4                                         FOOD SCIENCE
# 5                           PLANT SCIENCE AND AGRONOMY
# 6                                         SOIL SCIENCE
# 7                            MISCELLANEOUS AGRICULTURE
# 8                                ENVIRONMENTAL SCIENCE
# 9                                             FORESTRY
# 10                        NATURAL RESOURCES MANAGEMENT
# 11                                        ARCHITECTURE
# 12                AREA ETHNIC AND CIVILIZATION STUDIES
# 13                                      COMMUNICATIONS
# 14                                          JOURNALISM
# 15                                          MASS MEDIA
# ...

# %% [markdown]
# ### 2. Show the count of missing values in each column

# %%
majors1.isnull().sum()
# Out:
# Major                0
# Major_category       0
# Total                0
# Employed             0
# Unemployed           0
# Unemployment_rate    0
# Median               0
# P25th                0
# P75th                0
# dtype: int64

# %% [markdown]
# ### 3. What are the top 10 highest paying majors?

# %%
majors2 = majors1.sort_values("P75th").tail(10)
majors2
# Out:
#                                                  Major  \
# 48                              ELECTRICAL ENGINEERING
# 45                                CHEMICAL ENGINEERING
# 55                           METALLURGICAL ENGINEERING
# 56                      MINING AND MINERAL ENGINEERING
# 154  PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTR...
# 51              GEOLOGICAL AND GEOPHYSICAL ENGINEERING
# 57           NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 58                                 NUCLEAR ENGINEERING
# 97                    MATHEMATICS AND COMPUTER SCIENCE
# 59                               PETROLEUM ENGINEERING
#
#               Major_category   Total  Employed  Unemployed  Unemployment_rate  \
# 48               Engineering  671647    489965       26064           0.050509
# 45               Engineering  188046    131697        6388           0.046261
# 55               Engineering   12818      6939         326           0.044873
# ...

# %% [markdown]
# ### 4. Plot the data from the last question in a bar chart, include proper title, and labels

# %%
MajorsName = ["Petroleum Engineering", "Mathematics/Computer Science", "Nuclear Engineering", "Naval Architecture/Marine Engineering",
             "Geological/Geophysical Engineering", "Pharmacy Sciences/Admin", "Mining/Mineral Engineering", "Metallurgical Engineering", "Chemical Engineering", 
             "Electrical Engineering"]
PayRate = [210000, 136000, 128000, 125000, 125000, 125000, 124000, 123000, 120000, 116000]
pos = np.arange(len(PayRate))
w = 0.4
plt.bar(x=pos, width=w, height=PayRate,tick_label=MajorsName, align="center")
plt.xticks(fontsize=8, rotation='vertical')
plt.xlabel("Major Name",)
plt.ylabel("Annual Pay")
plt.title("Highest Paying Majors")
plt.show()

# %% [markdown]
# ### 5. What is the average median salary for each major category?

# %%
majors.groupby("P75th").median().head()
# Out:
#          Major_code     Total  Employed  Employed_full_time_year_round  \
# P75th
# 45800.0      2307.0  157079.0  113460.0                        71133.0
# 50000.0      2304.0   17633.0   13071.0                         8888.0
# 51000.0      2312.0   88067.0   58885.0                        37892.0
# 52000.0      4507.0   47731.0   35194.5                        25202.5
# 53000.0      3857.0  234426.0  166676.5                       117817.5
#
#          Unemployed  Unemployment_rate   Median    P25th
# P75th
# 45800.0      5890.0           0.049351  35300.0  27000.0
# 50000.0       954.0           0.068021  40000.0  31000.0
# 51000.0      2032.0           0.033357  40000.0  30000.0
# 52000.0      2729.5           0.070659  36500.0  28500.0
# 53000.0      9782.5           0.053260  41000.0  32000.0

# %% [markdown]
# ### 6. Visualize only the top 5 paying major categories

# %%
majors2.sort_values("P75th").tail(5)
# Out:
#                                         Major           Major_category  Total  \
# 51     GEOLOGICAL AND GEOPHYSICAL ENGINEERING              Engineering   6264
# 57  NAVAL ARCHITECTURE AND MARINE ENGINEERING              Engineering  16094
# 58                        NUCLEAR ENGINEERING              Engineering   9826
# 97           MATHEMATICS AND COMPUTER SCIENCE  Computers & Mathematics   7184
# 59                      PETROLEUM ENGINEERING              Engineering  19631
#
#     Employed  Unemployed  Unemployment_rate  Median  P25th     P75th
# 51      4120           0           0.000000   85000  55000  125000.0
# 57     10690         449           0.040309   97000  60000  125000.0
# 58      7320         527           0.067159   95000  65000  128000.0
# 97      5874         150           0.024900   92000  53000  136000.0
# 59     14002         617           0.042205  125000  75000  210000.0

# %% [markdown]
# ### 7. Plot a histogram of the distribution of median salaries

# %%
majors.groupby('Median').P75th.hist(figsize=(14,12))
# Out:
# Median
# 35000     AxesSubplot(0.125,0.125;0.775x0.755)
# 35300     AxesSubplot(0.125,0.125;0.775x0.755)
# 37600     AxesSubplot(0.125,0.125;0.775x0.755)
# 38000     AxesSubplot(0.125,0.125;0.775x0.755)
# 39000     AxesSubplot(0.125,0.125;0.775x0.755)
# 40000     AxesSubplot(0.125,0.125;0.775x0.755)
# 40500     AxesSubplot(0.125,0.125;0.775x0.755)
# 41000     AxesSubplot(0.125,0.125;0.775x0.755)
# 42000     AxesSubplot(0.125,0.125;0.775x0.755)
# 42600     AxesSubplot(0.125,0.125;0.775x0.755)
# 43000     AxesSubplot(0.125,0.125;0.775x0.755)
# 44000     AxesSubplot(0.125,0.125;0.775x0.755)
# 44500     AxesSubplot(0.125,0.125;0.775x0.755)
# 45000     AxesSubplot(0.125,0.125;0.775x0.755)
# 46000     AxesSubplot(0.125,0.125;0.775x0.755)
# 46600     AxesSubplot(0.125,0.125;0.775x0.755)
# 46700     AxesSubplot(0.125,0.125;0.775x0.755)
# 47000     AxesSubplot(0.125,0.125;0.775x0.755)
# 47500     AxesSubplot(0.125,0.125;0.775x0.755)
# 48000     AxesSubplot(0.125,0.125;0.775x0.755)
# ...

# %% [markdown]
#  8. Plot a histogram of the distribution of median salaries by major category

# %%
majors.hist('Median', by='Major_category', figsize=(14,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x115e03080>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e831748>]], dtype=object)

# %% [markdown]
# ### 9. What are the top 10 most UNemployed majors?

# %%
UnEmp = majors.sort_values(by="Unemployment_rate", ascending=False).head(10)
UnEmp
# Out:
#      Major_code                                     Major  \
# 146        6099                   MISCELLANEOUS FINE ARTS
# 116        5202                       CLINICAL PSYCHOLOGY
# 93         3801                     MILITARY TECHNOLOGIES
# 27         2303                 SCHOOL STUDENT COUNSELING
# 77         3501                           LIBRARY SCIENCE
# 141        6003                VISUAL AND PERFORMING ARTS
# 19         2101  COMPUTER PROGRAMMING AND DATA PROCESSING
# 119        5206                         SOCIAL PSYCHOLOGY
# 104        5001                ASTRONOMY AND ASTROPHYSICS
# 11         1401                              ARCHITECTURE
#
#                           Major_category   Total  Employed  \
# 146                                 Arts    8511      6431
# 116             Psychology & Social Work    7638      5128
# 93   Industrial Arts & Consumer Services    4315      1650
# 27                             Education    2396      1492
# ...

# %% [markdown]
# ### 10. What are the top 10 most UNemployed majors CATEGORIES? Use the mean for each category

# %%
#Im having a hard time understanding the objective of this question 
majors.groupby('Major_category').count()
# Out:
#                                      Major_code  Major  Total  Employed  \
# Major_category
# Agriculture & Natural Resources              10     10     10        10
# Arts                                          8      8      8         8
# Biology & Life Science                       14     14     14        14
# Business                                     13     13     13        13
# Communications & Journalism                   4      4      4         4
# Computers & Mathematics                      11     11     11        11
# Education                                    16     16     16        16
# Engineering                                  29     29     29        29
# Health                                       12     12     12        12
# Humanities & Liberal Arts                    15     15     15        15
# Industrial Arts & Consumer Services           7      7      7         7
# Interdisciplinary                             1      1      1         1
# ...

# %% [markdown]
# ## Section 3: FIFA Soccer Game data

# %%
fifa = pd.read_csv('../data/fifa_data.csv')
fifa.head()
# Out:
#                 Name Nationality National_Position  National_Kit  \
# 0  Cristiano Ronaldo    Portugal                LS           7.0
# 1       Lionel Messi   Argentina                RW          10.0
# 2             Neymar      Brazil                LW          10.0
# 3        Luis Suárez     Uruguay                LS           9.0
# 4       Manuel Neuer     Germany                GK           1.0
#
#            Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  \
# 0   Real Madrid            LW       7.0   07/01/2009           2021.0      94
# 1  FC Barcelona            RW      10.0   07/01/2004           2018.0      93
# 2  FC Barcelona            LW      11.0   07/01/2013           2021.0      92
# 3  FC Barcelona            ST       9.0   07/11/2014           2021.0      92
# 4     FC Bayern            GK       1.0   07/01/2011           2021.0      92
#
#       ...      Long_Shots Curve Freekick_Accuracy Penalties  Volleys  \
# ...

# %% [markdown]
# ### 1. Clean up the dataset.
#
#     - Lowercase the column names
#     - Set the "name" column as the index
#     - Drop the following columns "national_position", "national_kit", "club_kit", "club_joining", and "contract_expiry"
#     - Get rid of all players who are goalkeepers and drop every column that starts with GK
#     - Drop every player whose rating is less than 70
#     - Convert the "height" and "weight" columns to float types
#     - Check to see if there any nulls, if so drop them from the dataset

# %%
fifa.columns = map(str.lower, fifa.columns)
fifa
# Out:
#                      name          nationality national_position  \
# 0       Cristiano Ronaldo             Portugal                LS
# 1            Lionel Messi            Argentina                RW
# 2                  Neymar               Brazil                LW
# 3             Luis Suárez              Uruguay                LS
# 4            Manuel Neuer              Germany                GK
# 5                  De Gea                Spain                GK
# 6      Robert Lewandowski               Poland                LS
# 7             Gareth Bale                Wales                RS
# 8      Zlatan Ibrahimović               Sweden               NaN
# 9        Thibaut Courtois              Belgium                GK
# 10         Jérôme Boateng              Germany               RCB
# 11            Eden Hazard              Belgium                LF
# 12            Luka Modrić              Croatia               NaN
# ...

# %%
fifa[fifa.club_position.str.contains("GK")==False]
# Out:
#                             name          nationality national_position  \
# 0              Cristiano Ronaldo             Portugal                LS
# 1                   Lionel Messi            Argentina                RW
# 2                         Neymar               Brazil                LW
# 3                    Luis Suárez              Uruguay                LS
# 6             Robert Lewandowski               Poland                LS
# 7                    Gareth Bale                Wales                RS
# 8             Zlatan Ibrahimović               Sweden               NaN
# 10                Jérôme Boateng              Germany               RCB
# 11                   Eden Hazard              Belgium                LF
# 12                   Luka Modrić              Croatia               NaN
# 13                    Mesut Özil              Germany               CAM
# 14               Gonzalo Higuaín            Argentina               Sub
# ...

# %%
fifa.drop(["national_position", "national_kit", "club_kit", "club_joining", "contract_expiry"], axis=1, inplace=True)
fifa
# Out:
#                      name          nationality             club club_position  \
# 0       Cristiano Ronaldo             Portugal      Real Madrid            LW
# 1            Lionel Messi            Argentina     FC Barcelona            RW
# 2                  Neymar               Brazil     FC Barcelona            LW
# 3             Luis Suárez              Uruguay     FC Barcelona            ST
# 4            Manuel Neuer              Germany        FC Bayern            GK
# 5                  De Gea                Spain   Manchester Utd            GK
# 6      Robert Lewandowski               Poland        FC Bayern            ST
# 7             Gareth Bale                Wales      Real Madrid            RW
# 8      Zlatan Ibrahimović               Sweden   Manchester Utd            ST
# 9        Thibaut Courtois              Belgium          Chelsea            GK
# 10         Jérôme Boateng              Germany        FC Bayern           Sub
# ...

# %%
for col in fifa.columns:
    if 'gk' in col:
        del fifa[col]
fifa
# Out:
#                      name          nationality             club club_position  \
# 0       Cristiano Ronaldo             Portugal      Real Madrid            LW
# 1            Lionel Messi            Argentina     FC Barcelona            RW
# 2                  Neymar               Brazil     FC Barcelona            LW
# 3             Luis Suárez              Uruguay     FC Barcelona            ST
# 4            Manuel Neuer              Germany        FC Bayern            GK
# 5                  De Gea                Spain   Manchester Utd            GK
# 6      Robert Lewandowski               Poland        FC Bayern            ST
# 7             Gareth Bale                Wales      Real Madrid            RW
# 8      Zlatan Ibrahimović               Sweden   Manchester Utd            ST
# 9        Thibaut Courtois              Belgium          Chelsea            GK
# 10         Jérôme Boateng              Germany        FC Bayern           Sub
# ...

# %%
fifa.set_index("name", inplace=True)
fifa
# Out:
#                             nationality             club club_position  \
# name
# Cristiano Ronaldo              Portugal      Real Madrid            LW
# Lionel Messi                  Argentina     FC Barcelona            RW
# Neymar                           Brazil     FC Barcelona            LW
# Luis Suárez                     Uruguay     FC Barcelona            ST
# Manuel Neuer                    Germany        FC Bayern            GK
# De Gea                            Spain   Manchester Utd            GK
# Robert Lewandowski               Poland        FC Bayern            ST
# Gareth Bale                       Wales      Real Madrid            RW
# Zlatan Ibrahimović               Sweden   Manchester Utd            ST
# Thibaut Courtois                Belgium          Chelsea            GK
# Jérôme Boateng                  Germany        FC Bayern           Sub
# Eden Hazard                     Belgium          Chelsea            LW
# ...

# %%
fifa.drop(fifa[fifa.rating < 70].index, inplace=True)
fifa
# Out:
#                           nationality              club club_position  rating  \
# name
# Cristiano Ronaldo            Portugal       Real Madrid            LW      94
# Lionel Messi                Argentina      FC Barcelona            RW      93
# Neymar                         Brazil      FC Barcelona            LW      92
# Luis Suárez                   Uruguay      FC Barcelona            ST      92
# Manuel Neuer                  Germany         FC Bayern            GK      92
# De Gea                          Spain    Manchester Utd            GK      90
# Robert Lewandowski             Poland         FC Bayern            ST      90
# Gareth Bale                     Wales       Real Madrid            RW      90
# Zlatan Ibrahimović             Sweden    Manchester Utd            ST      90
# Thibaut Courtois              Belgium           Chelsea            GK      89
# Jérôme Boateng                Germany         FC Bayern           Sub      89
# ...

# %%
fifa["height"] = fifa.height.str.replace("cm", "")
fifa["weight"] = fifa.weight.str.replace("kg", "")
fifa
# Out:
#                           nationality              club club_position  rating  \
# name
# Cristiano Ronaldo            Portugal       Real Madrid            LW      94
# Lionel Messi                Argentina      FC Barcelona            RW      93
# Neymar                         Brazil      FC Barcelona            LW      92
# Luis Suárez                   Uruguay      FC Barcelona            ST      92
# Manuel Neuer                  Germany         FC Bayern            GK      92
# De Gea                          Spain    Manchester Utd            GK      90
# Robert Lewandowski             Poland         FC Bayern            ST      90
# Gareth Bale                     Wales       Real Madrid            RW      90
# Zlatan Ibrahimović             Sweden    Manchester Utd            ST      90
# Thibaut Courtois              Belgium           Chelsea            GK      89
# Jérôme Boateng                Germany         FC Bayern           Sub      89
# ...

# %%
fifa["height"] = fifa.height.astype(float)
fifa
# Out:
#                           nationality              club club_position  rating  \
# name
# Cristiano Ronaldo            Portugal       Real Madrid            LW      94
# Lionel Messi                Argentina      FC Barcelona            RW      93
# Neymar                         Brazil      FC Barcelona            LW      92
# Luis Suárez                   Uruguay      FC Barcelona            ST      92
# Manuel Neuer                  Germany         FC Bayern            GK      92
# De Gea                          Spain    Manchester Utd            GK      90
# Robert Lewandowski             Poland         FC Bayern            ST      90
# Gareth Bale                     Wales       Real Madrid            RW      90
# Zlatan Ibrahimović             Sweden    Manchester Utd            ST      90
# Thibaut Courtois              Belgium           Chelsea            GK      89
# Jérôme Boateng                Germany         FC Bayern           Sub      89
# ...

# %%
fifa["weight"] = fifa.weight.astype(float)
fifa
# Out:
#                           nationality              club club_position  rating  \
# name
# Cristiano Ronaldo            Portugal       Real Madrid            LW      94
# Lionel Messi                Argentina      FC Barcelona            RW      93
# Neymar                         Brazil      FC Barcelona            LW      92
# Luis Suárez                   Uruguay      FC Barcelona            ST      92
# Manuel Neuer                  Germany         FC Bayern            GK      92
# De Gea                          Spain    Manchester Utd            GK      90
# Robert Lewandowski             Poland         FC Bayern            ST      90
# Gareth Bale                     Wales       Real Madrid            RW      90
# Zlatan Ibrahimović             Sweden    Manchester Utd            ST      90
# Thibaut Courtois              Belgium           Chelsea            GK      89
# Jérôme Boateng                Germany         FC Bayern           Sub      89
# ...

# %%
fifa.dropna(inplace=True)
fifa
# Out:
#                           nationality              club club_position  rating  \
# name
# Cristiano Ronaldo            Portugal       Real Madrid            LW      94
# Lionel Messi                Argentina      FC Barcelona            RW      93
# Neymar                         Brazil      FC Barcelona            LW      92
# Luis Suárez                   Uruguay      FC Barcelona            ST      92
# Manuel Neuer                  Germany         FC Bayern            GK      92
# De Gea                          Spain    Manchester Utd            GK      90
# Robert Lewandowski             Poland         FC Bayern            ST      90
# Gareth Bale                     Wales       Real Madrid            RW      90
# Zlatan Ibrahimović             Sweden    Manchester Utd            ST      90
# Thibaut Courtois              Belgium           Chelsea            GK      89
# Jérôme Boateng                Germany         FC Bayern           Sub      89
# ...

# %% [markdown]
# ### 2.  Who are the top five players of the following attributes: speed, marking, and finishing

# %%
fifa.sort_values(['speed', 'marking', 'finishing'], ascending=False).head()
# Out:
#                           nationality             club club_position  rating  \
# name
# Pierre-Emerick Aubameyang       Gabon    Bor. Dortmund            ST      87
# Jonathan Biabiany              France            Inter           Sub      76
# Gareth Bale                     Wales      Real Madrid            RW      90
# Ernest Asante                   Ghana  FC Nordsjælland            RW      70
# Jürgen Damm                    Mexico           Tigres            RM      74
#
#                            height  weight preffered_foot  birth_date  age  \
# name
# Pierre-Emerick Aubameyang   187.0    80.0          Right  06/18/1989   27
# Jonathan Biabiany           177.0    73.0          Right  04/28/1988   28
# Gareth Bale                 183.0    74.0           Left  07/16/1989   27
# Ernest Asante               171.0    69.0          Right  11/06/1988   28
# Jürgen Damm                 187.0    69.0          Right  11/07/1992   24
#
# ...

# %% [markdown]
# ### 3. Who is the tallest French lefted foot player?

# %%
TallLeftFR = fifa[(fifa.nationality=="France") & (fifa.preffered_foot=="Left")]
TallLeftFR.sort_values('height', ascending=False).head(1)
# Out:
#               nationality        club club_position  rating  height  weight  \
# name
# Romain Thomas      France  Angers SCO           LCB      78   193.0    84.0
#
#               preffered_foot  birth_date  age preffered_position   ...     \
# name                                                               ...
# Romain Thomas           Left  06/12/1988   28                 CB   ...
#
#               agility  jumping  heading  shot_power  finishing  long_shots  \
# name
# Romain Thomas      54       68       79          60         19          24
#
#                curve  freekick_accuracy  penalties  volleys
# name
# Romain Thomas     39                 34         52       18
#
# [1 rows x 42 columns]

# %% [markdown]
# ### 4. Show a pandas series of every attribute's correlation with the rating attribute

# %%
fifa.corr()
# Out:
#                       rating    height    weight       age  weak_foot  \
# rating              1.000000  0.053331  0.062750  0.053204   0.117786
# height              0.053331  1.000000  0.788570  0.065015  -0.221324
# weight              0.062750  0.788570  1.000000  0.172032  -0.182188
# age                 0.053204  0.065015  0.172032  1.000000  -0.030935
# weak_foot           0.117786 -0.221324 -0.182188 -0.030935   1.000000
# skill_moves         0.138227 -0.495063 -0.452793 -0.168267   0.331349
# ball_control        0.182954 -0.468986 -0.449450 -0.178940   0.335171
# dribbling           0.145437 -0.539310 -0.511238 -0.222599   0.347762
# marking             0.030526  0.020675  0.003524  0.008905  -0.072224
# sliding_tackle      0.051110 -0.010354 -0.027059 -0.006995  -0.064493
# standing_tackle     0.061214 -0.002075 -0.021143 -0.006195  -0.043917
# aggression          0.099038 -0.025534  0.006640  0.055030   0.042790
# ...

# %% [markdown]
# ### 5. Make a heatmap of the dataset's correlation table

# %%
sns.heatmap(fifa.corr())

# %% [markdown]
# ### 6. Return a dataframe with only players from the following clubs. Call the dataframe fifa2. From now on we'll be using fifa2

# %%
clubs_list = ['Real Madrid', 'FC Barcelona', 'FC Bayern', 'Manchester Utd',
       'Chelsea', 'Arsenal', 'Juventus', 'PSG', 'Manchester City',
              'Bor. Dortmund', 'Liverpool', 'Roma']

# %%
fifa["club"] = fifa.club.str.replace(" ", "_")
fifa.head()
# Out:
#                   nationality          club club_position  rating  height  \
# name
# Cristiano Ronaldo    Portugal   Real_Madrid            LW      94   185.0
# Lionel Messi        Argentina  FC_Barcelona            RW      93   170.0
# Neymar                 Brazil  FC_Barcelona            LW      92   174.0
# Luis Suárez           Uruguay  FC_Barcelona            ST      92   182.0
# Manuel Neuer          Germany     FC_Bayern            GK      92   193.0
#
#                    weight preffered_foot  birth_date  age preffered_position  \
# name
# Cristiano Ronaldo    80.0          Right  02/05/1985   32              LW/ST
# Lionel Messi         72.0           Left  06/24/1987   29                 RW
# Neymar               68.0          Right  02/05/1992   25                 LW
# Luis Suárez          85.0          Right  01/24/1987   30                 ST
# Manuel Neuer         92.0          Right  03/27/1986   31                 GK
#
# ...

# %%
fifa2 = fifa.loc[fifa['club'].isin(['Juventus', 'Liverpool', 'Real_Madrid', 'FC_Barcelona', 'FC_Bayern', 'Manchester_Utd', 
                                     'Chelsea', 'Arsenal', 'PSG', 'Manchester_City', 'Bor._Dortmund', 'Roma'])]
fifa2
# Out:
#                             nationality             club club_position  \
# name
# Cristiano Ronaldo              Portugal      Real_Madrid            LW
# Lionel Messi                  Argentina     FC_Barcelona            RW
# Neymar                           Brazil     FC_Barcelona            LW
# Luis Suárez                     Uruguay     FC_Barcelona            ST
# Manuel Neuer                    Germany        FC_Bayern            GK
# De Gea                            Spain   Manchester_Utd            GK
# Robert Lewandowski               Poland        FC_Bayern            ST
# Gareth Bale                       Wales      Real_Madrid            RW
# Zlatan Ibrahimović               Sweden   Manchester_Utd            ST
# Thibaut Courtois                Belgium          Chelsea            GK
# Jérôme Boateng                  Germany        FC_Bayern           Sub
# Eden Hazard                     Belgium          Chelsea            LW
# ...

# %% [markdown]
# ### 8. Make a scatter plot of short_pass vs marking and use the preffered_foot column to color-encode the dots.

# %% [markdown]
# ### 7. Make a bar plot of the average long_shots, curve, and dribbling attributes of the clubs in the data

# %%
cols = ["long_shots", "curve", "dribbling"]
Av = fifa2[cols]
Av1 = Av.mean()
Av1.plot(kind='bar')

# %%
fifa2.plot.scatter(x='short_pass', y='marking')

# %% [markdown]
# 9. Make a grouped boxplots using club_position as the x axis for the following attributes: dribbling, balance, and sliding_tackle

# %%
fifa2.boxplot(['dribbling', 'balance', 'sliding_tackle'], 'club_position', figsize=(22,20)) #Im not sure what happened with the labeling and x axis for dribbling..
# Out:
# /Users/TJR/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a2068c630>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d33e3c8>]], dtype=object)

# %% [markdown]
# Which position is better at dribbling? ST or RCM? Why?

# %%
#Balance boxplot #ANSWER - RCM because of density is in a higher value than ST out of 100

# %% [markdown]
# Which position is better at balance? LM or LDM? Why?

# %%
#ANSWER - LM Median is slight higher than LDM

# %%
#sliding_tackle boxplot

# %% [markdown]
# What is the IQR for positions ST, RB, and RM?

# %%
#QUESTION - Is there a way to find the the integer for Q1 and Q3 without looking at the dataset? like a code or something like that.

# %%
#Interquartile Range (IQR) - The interquartile range is a measure of where the “middle fifty” is in a data set. 
#Where a range is a measure of where the beginning and end are in a set, an interquartile range is a measure of where the bulk of the values lie. 
#That’s why it’s preferred over many other measures of spread (i.e. the average or median) when reporting things like school performance or SAT scores.

#The interquartile range formula is the first quartile subtracted from the third quartile:
#IQR = Q3 – Q1.

#Steps:
#Step 1: Put the numbers in order.
#1, 2, 5, 6, 7, 9, 12, 15, 18, 19, 27.
#Step 2: Find the median.
#1, 2, 5, 6, 7, 9, 12, 15, 18, 19, 27.
#Step 3: Place parentheses around the numbers above and below the median. 
#Not necessary statistically, but it makes Q1 and Q3 easier to spot.
#(1, 2, 5, 6, 7), 9, (12, 15, 18, 19, 27).
#Step 4: Find Q1 and Q3
#Think of Q1 as a median in the lower half of the data and think of Q3 as a median for the upper half of data.
#(1, 2, 5, 6, 7),  9, ( 12, 15, 18, 19, 27). Q1 = 5 and Q3 = 18.
#Step 5: Subtract Q1 from Q3 to find the interquartile range.
#18 – 5 = 13.

# %%
#ST Balance 21
#ST Sliding Tackle 18
#RB Balance 10
#RB Sliding Tackle 7
#RM Balance 5
#RM Sliding Tackle 42
